# %%
#Mohamed Jaasir Subair
#2022bcs0010

import cv2
import os
import numpy as np

# %%
input_dir = "plant-disease/Tomato___Bacterial_spot"
output_dir = "output/Tomato___Bacterial_spot"
os.makedirs(output_dir, exist_ok=True)

for file in os.listdir(input_dir):
    if file.lower().endswith(('.jpg', '.png', '.jpeg')):
        img = cv2.imread(os.path.join(input_dir, file)) 

        lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
        l, a, b = cv2.split(lab)

        clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
        l_eq = clahe.apply(l)

        lab_eq = cv2.merge((l_eq, a, b))
        img_eq = cv2.cvtColor(lab_eq, cv2.COLOR_LAB2BGR)

        cv2.imwrite(os.path.join(output_dir, file), img_eq)

# %%
input_dir = "plant-disease/Tomato___Tomato_Yellow_Leaf_Curl_Virus"
output_dir = "output/Tomato___Tomato_Yellow_Leaf_Curl_Virus"
os.makedirs(output_dir, exist_ok=True)

for file in os.listdir(input_dir):
    if file.lower().endswith(('.jpg', '.png', '.jpeg')):
        img = cv2.imread(os.path.join(input_dir, file)) 

        lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
        l, a, b = cv2.split(lab)

        clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
        l_eq = clahe.apply(l)

        lab_eq = cv2.merge((l_eq, a, b))
        img_eq = cv2.cvtColor(lab_eq, cv2.COLOR_LAB2BGR)

        cv2.imwrite(os.path.join(output_dir, file), img_eq)

# %%
input_dir = "plant-disease/Tomato___Tomato_mosaic_virus"
output_dir = "output/Tomato___Tomato_mosaic_virus"
os.makedirs(output_dir, exist_ok=True)

for file in os.listdir(input_dir):
    if file.lower().endswith(('.jpg', '.png', '.jpeg')):
        img = cv2.imread(os.path.join(input_dir, file)) 

        lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
        l, a, b = cv2.split(lab)

        clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
        l_eq = clahe.apply(l)

        lab_eq = cv2.merge((l_eq, a, b))
        img_eq = cv2.cvtColor(lab_eq, cv2.COLOR_LAB2BGR)

        cv2.imwrite(os.path.join(output_dir, file), img_eq)

# %%
input_dir = "plant-disease/Tomato___Target_Spot"
output_dir = "output/Tomato___Target_Spot"
os.makedirs(output_dir, exist_ok=True)

for file in os.listdir(input_dir):
    if file.lower().endswith(('.jpg', '.png', '.jpeg')):
        img = cv2.imread(os.path.join(input_dir, file)) 

        lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
        l, a, b = cv2.split(lab)

        clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
        l_eq = clahe.apply(l)

        lab_eq = cv2.merge((l_eq, a, b))
        img_eq = cv2.cvtColor(lab_eq, cv2.COLOR_LAB2BGR)

        cv2.imwrite(os.path.join(output_dir, file), img_eq)

# %%
input_dir = "plant-disease/Tomato___Target_Spot"
output_dir = "output/Tomato___Target_Spot"
os.makedirs(output_dir, exist_ok=True)

for file in os.listdir(input_dir):
    if file.lower().endswith(('.jpg', '.png', '.jpeg')):
        img = cv2.imread(os.path.join(input_dir, file)) 

        lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
        l, a, b = cv2.split(lab)

        clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
        l_eq = clahe.apply(l)

        lab_eq = cv2.merge((l_eq, a, b))
        img_eq = cv2.cvtColor(lab_eq, cv2.COLOR_LAB2BGR)

        cv2.imwrite(os.path.join(output_dir, file), img_eq)

# %%
input_dir = "plant-disease/Tomato___Septoria_leaf_spot"
output_dir = "output/Tomato___Septoria_leaf_spot"
os.makedirs(output_dir, exist_ok=True)

for file in os.listdir(input_dir):
    if file.lower().endswith(('.jpg', '.png', '.jpeg')):
        img = cv2.imread(os.path.join(input_dir, file)) 

        lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
        l, a, b = cv2.split(lab)

        clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
        l_eq = clahe.apply(l)

        lab_eq = cv2.merge((l_eq, a, b))
        img_eq = cv2.cvtColor(lab_eq, cv2.COLOR_LAB2BGR)

        cv2.imwrite(os.path.join(output_dir, file), img_eq)

# %%
input_dir = "plant-disease/Tomato___Leaf_Mold"
output_dir = "output/Tomato___Leaf_Mold"
os.makedirs(output_dir, exist_ok=True)

for file in os.listdir(input_dir):
    if file.lower().endswith(('.jpg', '.png', '.jpeg')):
        img = cv2.imread(os.path.join(input_dir, file)) 

        lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
        l, a, b = cv2.split(lab)

        clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
        l_eq = clahe.apply(l)

        lab_eq = cv2.merge((l_eq, a, b))
        img_eq = cv2.cvtColor(lab_eq, cv2.COLOR_LAB2BGR)

        cv2.imwrite(os.path.join(output_dir, file), img_eq)

# %%
input_dir = "plant-disease/Tomato___Late_blight"
output_dir = "output/Tomato___Late_blight"
os.makedirs(output_dir, exist_ok=True)

for file in os.listdir(input_dir):
    if file.lower().endswith(('.jpg', '.png', '.jpeg')):
        img = cv2.imread(os.path.join(input_dir, file)) 

        lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
        l, a, b = cv2.split(lab)

        clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
        l_eq = clahe.apply(l)

        lab_eq = cv2.merge((l_eq, a, b))
        img_eq = cv2.cvtColor(lab_eq, cv2.COLOR_LAB2BGR)

        cv2.imwrite(os.path.join(output_dir, file), img_eq)

# %%
input_dir = "plant-disease/Tomato___Early_blight"
output_dir = "output/Tomato___Early_blight"
os.makedirs(output_dir, exist_ok=True)

for file in os.listdir(input_dir):
    if file.lower().endswith(('.jpg', '.png', '.jpeg')):
        img = cv2.imread(os.path.join(input_dir, file)) 

        lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
        l, a, b = cv2.split(lab)

        clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
        l_eq = clahe.apply(l)

        lab_eq = cv2.merge((l_eq, a, b))
        img_eq = cv2.cvtColor(lab_eq, cv2.COLOR_LAB2BGR)

        cv2.imwrite(os.path.join(output_dir, file), img_eq)
